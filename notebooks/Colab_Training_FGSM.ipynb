# %%
# 1. Mount your Google Drive (so your trained model saves permanently and isn't lost when Colab closes)
from google.colab import drive
drive.mount('/content/drive')

# 2. Clone your project (replace with your actual github link)
# !git clone https://github.com/lionelishi21/fgsm-vision-engine.git
# %cd fgsm-vision-engine

# 3. Install the required libraries
# !pip install -r requirements.txt

# 4. Start the Training!
# !python src/train_temporal_classifier.py --config configs/temporal_classifier.yaml
# !python src/train_hitbox_segmentation.py --data data/ufd/segmentation_dataset --output /content/drive/MyDrive/fgsm_models/hitbox_segmenter
