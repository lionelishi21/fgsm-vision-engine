# %%
import os

# 1. Clone the project (only if it hasn't been cloned yet)
if not os.path.exists('/content/fgsm-vision-engine'):
  # !git clone https://github.com/lionelishi21/fgsm-vision-engine.git

# 2. Force Colab to move into the exact folder
# %cd /content/fgsm-vision-engine

# 3. Install the required libraries
# !pip install -r requirements.txt

# 4. Start the Training!
# !python src/train_temporal_classifier.py --config configs/temporal_classifier.yaml

# Save the final output locally since Google Drive mounting is failing
# !python src/train_hitbox_segmentation.py --data data/ufd/segmentation_dataset --output runs/hitbox_segmenter
